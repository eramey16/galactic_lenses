# %%
import sys
import os
sys.path.insert(0, '/home/jovyan/frankenblast-host')
os.environ['SPS_HOME'] = '/home/jovyan/fsps'
os.environ['SBIPP_TRAINING_ROOT'] = '/home/jovyan/frankenblast-host/data/sbi_training_sets'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fit_host_sed import fit_host, maggies_to_asinh
from fit_host_sed import run_training_set, build_obs, build_model, fit_sbi_pp, build_model_nonparam
from frankenblast import run_single
# Out:
# 2026-03-20 00:36:38.886270: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-20 00:36:38.904401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773966998.930323    1260 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773966998.937845    1260 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
data = pd.read_csv("data/lensed_dr10_all.dat")

# %%
# list(data.columns)

# %%
gal = data.iloc[0]
run_single(str(gal.ls_id), gal.ra, gal.dec, gal.dered_flux_g, gal.flux_ivar_g, gal.dered_flux_r, gal.flux_ivar_r, 
           gal.dered_flux_i, gal.flux_ivar_i, gal.dered_flux_z, gal.flux_ivar_z, gal.dered_flux_w1, gal.flux_ivar_w1, 
           gal.dered_flux_w2, gal.flux_ivar_w2, mwebv=0, redshift=gal.z_phot_median
          )
# Out:
# ...
# Fitting: 10995286950286814  (ra=3.6095, dec=-30.3821, z=0.2530647)
# ...
# MW E(B-V) = 0.0000
#   PanSTARRS_g : flux=6.050e-09, err=2.582e-11 maggies
#   PanSTARRS_r : flux=2.101e-08, err=4.647e-11 maggies
#   PanSTARRS_i : flux=3.168e-08, err=7.811e-11 maggies
#   PanSTARRS_z : flux=4.199e-08, err=1.055e-10 maggies
#   WISE_W1     : flux=5.078e-08, err=6.360e-10 maggies
#   WISE_W2     : flux=3.317e-08, err=1.302e-09 maggies
# Loaded observations and model
# starting model fit
# Loading training sets from data files...
# Training sets loaded.
# Host has spectroscopic redshift.
# sbi missing and noisy bands
# [10 12]
# Failed to find sufficient number of nearest neighbors!
# _chi2_thres 5005 > max_chi2 5000 200
# Failed to find sufficient number of nearest neighbors!
# Clipping the Gaussian, from which we MC noise, to be within the min & max of the magnitude at that band in the training set
# WARNING:root:Only 0.129% proposal samples are
# ...

# %%
from get_host_images import survey_list
surveys = survey_list("/home/jovyan/frankenblast-host/data/survey_frankenblast_metadata.yml")
print(surveys)

# %%
from classes import Filter

# %%
[x.name for x in Filter.all()]
# Out:
# ['2MASS_H',
#  '2MASS_J',
#  '2MASS_K',
#  'WISE_W1',
#  'WISE_W2',
#  'WISE_W3',
#  'WISE_W4',
#  'GALEX_NUV',
#  'GALEX_FUV',
#  'PanSTARRS_g',
#  'PanSTARRS_r',
#  'PanSTARRS_i',
#  'PanSTARRS_z',
#  'PanSTARRS_y',
#  'DES_g',
#  'DES_r',
#  'DES_i',
#  'DES_z']

# %%
import os
print("Working directory:", os.getcwd())
# Out:
# Working directory: /home/jovyan/galactic_lenses
