# %%
import sys
import os
sys.path.insert(0, '/home/jovyan/frankenblast-host')
os.environ['SPS_HOME'] = '/home/jovyan/fsps'
os.environ['SBIPP_TRAINING_ROOT'] = '/home/jovyan/frankenblast-host/data/sbi_training_sets'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from fit_host_sed import fit_host, maggies_to_asinh
# from fit_host_sed import run_training_set, build_obs, build_model, fit_sbi_pp, build_model_nonparam
from frankenblast import run_single
# Out:
# 2026-03-20 18:36:24.332303: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-20 18:36:24.349724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774031784.371880     251 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774031784.379802     251 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-20 18:36:24.405855: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv("data/lensed_dr10_all.dat")

# %%
# list(data.columns)

# %%
gal = data.iloc[0]
run_single(str(gal.ls_id), gal.ra, gal.dec, redshift = gal.z_phot_median)
# Out:
# ============================================================
# Fitting: 10995286950286814  (ra=3.6095, dec=-30.3821, z=0.2530647)
# ============================================================
# Looking up MW E(B-V) from SFD maps...
# MW E(B-V) = 0.0114
# Downloading cutout images...
# Processing filter: 2MASS_H from survey 2MASS
# File already exists and overwrite is False: ./cutouts/10995286950286814/2MASS/2MASS_H.fits
# Processing filter: 2MASS_J from survey 2MASS
# File already exists and overwrite is False: ./cutouts/10995286950286814/2MASS/2MASS_J.fits
# Processing filter: 2MASS_K from survey 2MASS
# File already exists and overwrite is False: ./cutouts/10995286950286814/2MASS/2MASS_K.fits
# Processing filter: WISE_W1 from survey WISE
# File already exists and overwrite is False: ./cutouts/10995286950286814/WISE/WISE_W1.fits
# Processing filter: WISE_W2 from survey WISE
# File already exists and overwrite is False: ./cutouts/10995286950286814/WISE/WISE_W2.fits
# Processing filter: WISE_W3 from survey WISE
# File already exists and overwrite is False: ./cutouts/10995286950286814/WISE/WISE_W3.fits
# Processing filter: WISE_W4 from survey WISE
# File already exists and overwrite is False: ./cutouts/10995286950286814/WISE/WISE_W4.fits
# Processing filter: GALEX_NUV from survey AIS
# File already exists and overwrite is False: ./cutouts/10995286950286814/AIS/GALEX_NUV.fits
# Processing filter: GALEX_FUV from survey AIS
# File already exists and overwrite is False: ./cutouts/10995286950286814/AIS/GALEX_FUV.fits
# Processing filter: PanSTARRS_g from survey DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DR1/PanSTARRS_g.fits
# Processing filter: PanSTARRS_r from survey DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DR1/PanSTARRS_r.fits
# Processing filter: PanSTARRS_i from survey DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DR1/PanSTARRS_i.fits
# Processing filter: PanSTARRS_z from survey DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DR1/PanSTARRS_z.fits
# Processing filter: PanSTARRS_y from survey DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DR1/PanSTARRS_y.fits
# Processing filter: DES_g from survey DES-DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DES-DR1/DES_g.fits
# Processing filter: DES_r from survey DES-DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DES-DR1/DES_r.fits
# Processing filter: DES_z from survey DES-DR1
# File already exists and overwrite is False: ./cutouts/10995286950286814/DES-DR1/DES_z.fits
# Constructing apertures and doing photometry...
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2013-03-22T22:29:08.055' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-05-25T06:20:37.051' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2013-09-17T01:58:06.086' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-08-15T23:48:31.630' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-10-15T09:05:52.420' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: NoDetectionsWarning: No sources were found. [photutils.segmentation.detect]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2013-03-22T22:29:08.055' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-05-25T06:20:37.051' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2013-09-17T01:58:06.086' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-08-15T23:48:31.630' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-10-15T09:05:52.420' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# no apr
# no apr
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# no apr
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# no apr
# /home/jovyan/frankenblast-host/do_photometry.py:249: RuntimeWarning: invalid value encountered in log10
#   return -2.5 * np.log10(flux) + zero_point_mag
# no apr
# /home/jovyan/frankenblast-host/do_photometry.py:249: RuntimeWarning: invalid value encountered in log10
#   return -2.5 * np.log10(flux) + zero_point_mag
# Loaded observations and model
# starting model fit
# Loading training sets from data files...
# Training sets loaded.
# Host has spectroscopic redshift.
# sbi missing bands
# mc samples: 10
# WARNING:root:Only 0.716% proposal samples are
#                     accepted. It may take a long time to collect the remaining
#                     -22 samples. Consider interrupting (Ctrl-C) and switching to
#                     `build_posterior(..., sample_with='mcmc')`.
# mc samples: 20
# mc samples: 30
# WARNING:root:Only 0.965% proposal samples are
#                     accepted. It may take a long time to collect the remaining
#                     -47 samples. Consider interrupting (Ctrl-C) and switching to
#                     `build_posterior(..., sample_with='mcmc')`.
# mc samples: 40
# mc samples: 50
# /home/jovyan/galactic_lenses/data/10995286950286814/10995286950286814_global.h5
# Saved to h5 file
# /home/jovyan/envs/frankenblast/lib/python3.10/site-packages/prospect/io/write_results.py:60: RuntimeWarning: Could not store paramfile text
#   warnings.warn("Could not store paramfile text", RuntimeWarning)
# /home/jovyan/envs/frankenblast/lib/python3.10/site-packages/prospect/io/write_results.py:301: RuntimeWarning: Could not JSON serialize model_params, pickled instead
#   warnings.warn("Could not JSON serialize {}, pickled instead".format(k),
# Found best fit model SED.
# Host model and stellar population properties saved to /home/jovyan/galactic_lenses/data/10995286950286814/10995286950286814_global.npy.
# Fit completed in 20.14 min
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 gal = data.iloc[0]
# ----> 2 run_single(str(gal.ls_id), gal.ra, gal.dec, redshift = gal.z_phot_median)
#
# File ~/galactic_lenses/frankenblast.py:293, in run_single(name, ra, dec, redshift, mwebv, all_filters, download_cutouts)
#     290     traceback.print_exc()
#     291     return None
# --> 293 res = _load_results(name)
#     295 os.chdir(prev_dir)
#     297 return res
#
# File ~/galactic_lenses/frankenblast.py:147, in _load_results(name)
#     145     return None
#     146 model_dict = np.load(npy_path, allow_pickle=True).item(0)
# --> 147 mass_p16, mass_p50, mass_p84 = np.percentile(model_dict["stellar_mass"], [16, 50, 84])
#     148 sfr_p16,  sfr_p50,  sfr_p84  = np.percentile(model_dict["sfr"],          [16, 50, 84])
#     149 return {
#     150     "name":       name,
#     151     "mass_p16":   mass_p16,
#    (...)
#     157     "npy_path":   npy_path,
#     158 }
#
# KeyError: 'stellar_mass'
